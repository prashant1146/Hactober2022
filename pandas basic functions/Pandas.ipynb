# %%
import pandas as pd
import numpy as np

# %%
s=pd.read_csv("DOB.csv")

# %%
print(s)
# Out:
#   PRASHANT   5  8  2001
# 0   ADITYA  22  3  2004
# 1  KRITIKA  12  5  2007
# 2   ASHIKA   9  5  2009
# 3    VINOD  15  7  1971

# %%
dfe=pd.DataFrame(s)

# %%
#rename columns
dfe.rename(columns={'PRASHANT':'NAME','5':'DD','8':'MM','2001':'YYYY'},inplace=True)

# %%
dfe
# Out:
#       NAME  DD  MM  YYYY
# 0   ADITYA  22   3  2004
# 1  KRITIKA  12   5  2007
# 2   ASHIKA   9   5  2009
# 3    VINOD  15   7  1971

# %%
s
# Out:
#       NAME  DD  MM  YYYY
# 0   ADITYA  22   3  2004
# 1  KRITIKA  12   5  2007
# 2   ASHIKA   9   5  2009
# 3    VINOD  15   7  1971

# %%
#rename rows
dfe.rename(index={0:'R1',1:'R2',2:'R3',3:'R4',4:'R5',5:'R6',6:'R7'},inplace=True)

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY
# R1   ADITYA  22   3  2004
# R2  KRITIKA  12   5  2007
# R3   ASHIKA   9   5  2009
# R4    VINOD  15   7  1971

# %%
#add a new row 
dfe.append({'NAME':'PRASHANT','DD':5,'MM':8,'YYYY':2001},ignore_index=True)
# Out:
#        NAME  DD  MM  YYYY
# 0    ADITYA  22   3  2004
# 1   KRITIKA  12   5  2007
# 2    ASHIKA   9   5  2009
# 3     VINOD  15   7  1971
# 4  PRASHANT   5   8  2001

# %%
#drop a column named 'R5'
dfe.drop(['R5'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20352/2350146920.py in <module>
#       1 #drop a column named 'R5'
# ----> 2 dfe.drop(['R5'],axis=1,inplace=True)
#
# c:\Python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# c:\Python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY
# R1   ADITYA  22   3  2004
# R2  KRITIKA  12   5  2007
# R3   ASHIKA   9   5  2009
# R4    VINOD  15   7  1971

# %%
#add a row 
dfe.loc[4]=['PRASHANT',5,8,2001,np.nan,np.nan]

# %%
s
# Out:
#        NAME  DD  MM  YYYY  AGE
# R1   ADITYA  22   3  2004   17
# R2  KRITIKA  12   5  2007   15
# R3   ASHIKA   9   5  2009   12
# R4    VINOD  15   7  1971   45

# %%
dfe
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# R6     VISHU  29   2  2002  19.0   FATEHGARH
# R5  PRASHANT   5   8  2001   NaN         NaN

# %%
#add a column
dfe['AGE']=[17,15,12,45]
dfe
# Out:
#        NAME  DD  MM  YYYY  AGE
# R1   ADITYA  22   3  2004   17
# R2  KRITIKA  12   5  2007   15
# R3   ASHIKA   9   5  2009   12
# R4    VINOD  15   7  1971   45

# %%
#add values to NaN place
dfe.fillna(value=19,inplace=True)

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE
# R1   ADITYA  22   3  2004  17.0
# R2  KRITIKA  12   5  2007  15.0
# R3   ASHIKA   9   5  2009  12.0
# R4    VINOD  15   7  1971  45.0
# R6    VISHU  29   2  2002  19.0

# %%
#add a column
dfe=dfe.assign(Address=["BAGIA","PUNE",'KOTA','BARDHANIYA','FATEHGARH'])

# %%
dfe
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# R6     VISHU  29   2  2002  19.0   FATEHGARH
# R5  PRASHANT   5   8  2001   NaN         NaN

# %%
dfe
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# R5  PRASHANT   5   8  2001  19.0   FATEHGARH

# %%
dfe=dfe.append({'NAME':'VISHU','DD':5,'MM':8,'YYYY':2001},ignore_index=True)

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# 0    ADITYA  22   3  2004  17.0       BAGIA
# 1   KRITIKA  12   5  2007  15.0        PUNE
# 2    ASHIKA   9   5  2009  12.0        KOTA
# 3     VINOD  15   7  1971  45.0  BARDHANIYA
# 4  PRASHANT   5   8  2001  19.0   FATEHGARH
# 5     VISHU   5   8  2001   NaN         NaN

# %%
dfe.append({'NAME':'VISHU','DD':29,'MM':8,'YYYY':2001},ignore_index=True)
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# 0    ADITYA  22   3  2004  17.0       BAGIA
# 1   KRITIKA  12   5  2007  15.0        PUNE
# 2    ASHIKA   9   5  2009  12.0        KOTA
# 3     VINOD  15   7  1971  45.0  BARDHANIYA
# 4  PRASHANT   5   8  2001  19.0   FATEHGARH
# 5     VISHU   5   8  2001   NaN         NaN
# 6     VISHU  29   8  2001   NaN         NaN

# %%
print(dfe)
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# R6     VISHU  29   2  2002  19.0   FATEHGARH
# R5  PRASHANT   5   8  2001   NaN         NaN

# %%
dfe.append({'NAME':'VISHAL','DD':29,'MM':2,'YYYY':2002,'AGE':np.nan,'Address':np.nan},ignore_index=True)
# Out:
#       NAME  DD  MM  YYYY   AGE     Address
# 0   ADITYA  22   3  2004  17.0       BAGIA
# 1  KRITIKA  12   5  2007  15.0        PUNE
# 2   ASHIKA   9   5  2009  12.0        KOTA
# 3    VINOD  15   7  1971  45.0  BARDHANIYA
# 4   VISHAL  29   2  2002   NaN         NaN

# %%
dfe.rename(index={0:'R1',1:'R2',2:'R3',3:'R4',4:'R5',5:'R6',6:'R7'},inplace=True)

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# R1   ADITYA  22   3  2004  17.0       BAGIA
# R2  KRITIKA  12   5  2007  15.0        PUNE
# R3   ASHIKA   9   5  2009  12.0        KOTA
# R4    VINOD  15   7  1971  45.0  BARDHANIYA

# %%
dfe.drop('R5',axis=0,inplace=True)

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# R1   ADITYA  22   3  2004  17.0       BAGIA
# R2  KRITIKA  12   5  2007  15.0        PUNE
# R3   ASHIKA   9   5  2009  12.0        KOTA
# R4    VINOD  15   7  1971  45.0  BARDHANIYA

# %%
dfe.drop(5,axis=0)
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# 0    ADITYA  22   3  2004  17.0       BAGIA
# 1   KRITIKA  12   5  2007  15.0        PUNE
# 2    ASHIKA   9   5  2009  12.0        KOTA
# 3     VINOD  15   7  1971  45.0  BARDHANIYA
# 4  PRASHANT   5   8  2001  19.0   FATEHGARH

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# R1   ADITYA  22   3  2004  17.0       BAGIA
# R2  KRITIKA  12   5  2007  15.0        PUNE
# R3   ASHIKA   9   5  2009  12.0        KOTA
# R4    VINOD  15   7  1971  45.0  BARDHANIYA

# %%
dfe.drop(1,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-280c2244681f> in <module>
# ----> 1 dfe.drop(1,axis=0,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# R1   ADITYA  22   3  2004  17.0       BAGIA
# R2  KRITIKA  12   5  2007  15.0        PUNE
# R3   ASHIKA   9   5  2009  12.0        KOTA
# R4    VINOD  15   7  1971  45.0  BARDHANIYA

# %%
dfe
# Out:
#        NAME  DD  MM  YYYY   AGE     Address
# R1   ADITYA  22   3  2004  17.0       BAGIA
# R2  KRITIKA  12   5  2007  15.0        PUNE
# R3   ASHIKA   9   5  2009  12.0        KOTA
# R4    VINOD  15   7  1971  45.0  BARDHANIYA

# %%
dfe.loc['R6']=['VISHU',29,2,2002,18,'FATEHGARH']

# %%
dfe
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# 4   PRASHANT   5   8  2001  19.0   FATEHGARH
# R6     VISHU  29   2  2002  18.0   FATEHGARH

# %%
dfe.rename(index={4:'R5'},inplace=True)

# %%
dfe
# Out:
#         NAME  DD  MM  YYYY   AGE     Address
# R1    ADITYA  22   3  2004  17.0       BAGIA
# R2   KRITIKA  12   5  2007  15.0        PUNE
# R3    ASHIKA   9   5  2009  12.0        KOTA
# R4     VINOD  15   7  1971  45.0  BARDHANIYA
# R5  PRASHANT   5   8  2001  19.0   FATEHGARH
# R6     VISHU  29   2  2002  18.0   FATEHGARH
